# %%
list1=[(1,2),(3,4),(5,6),(4,5)]
list2=[]
for i in list1:
    list2.append(i[0]+i[1])
    
list2
# Out:
# [3, 7, 11, 9]

# %%
list2=[]
#with list comprehension
[list2.append(i[0]+i[1])  for i in list1]
list2
# Out:
# [3, 7, 11, 9]
